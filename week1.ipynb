# %%
# langkah 1
import numpy as np
import pandas as pd
import cv2 as cv

from google.colab.patches import cv2_imshow # image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

######
# membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571"]


# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list

# langkah 2

for url in urls:
  image = io.imread(url)  # read image
  image = cv.resize(image,(0,0),fx=0.5, fy=0.5) #resize image
  image_2 = cv.cvtColor(image,cv.COLOR_BGR2RGB) #conver color
  final_frame = cv.hconcat((image,image_2)) #concatenate
  cv2_imshow(final_frame) # show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# pertanyaan
#
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
# Jawab :
# Akses gratis ke GPU Google Colab memberikan akses gratis ke GPU yang sangat bermanfaat untuk komputasi yang memerlukan GPU seperti deep learning. Ini sangat sulit dan mahal untuk dilakukan secara lokal.
# Tidak perlu setup lingkungan Google Colab menyediakan lingkungan Python yang sudah terinstal dan siap pakai. Kita tidak perlu repot setup environment.
# Dukungan Google Drive Kita bisa menyimpan notebook dan data ke Google Drive sehingga hasilnya persistent.
# Dukungan library populer Google Colab dilengkapi library populer seperti TensorFlow, Keras, PyTorch, dan OpenCV yang siap digunakan.
# Performa tinggi Infrastruktur Google menyediakan akses jaringan berkecepatan tinggi serta resource komputasi terbaru.
#
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# Jawab :
# Numpy : untuk komputasi ilmiah dan analisis data karena menyediakan struktur data array multidimensi yang disebut ndarray, memiliki banyak fungsi matematika dan aljabar linier yang dapat dioperasikan pada array seperti penjumlahan, perkalian matriks, perhitungan statistik, dll.
#
# Pandas : memanipulasi dan menganalisis data karena menyediakan struktur data DataFrame mirip dengan tabel Excel atau SQL, Tool analitik seperti grouping, join, statistik deskriptif, visualisasi, dan time series, dll
#
# Cv2 : untuk computer vision dan pemrosesan gambar karena Menyediakan algoritma computer vision untuk mendeteksi, memproses, dan menganalisa gambar & video.
#
# Skimage : pemrosesan gambar karena Menyediakan algoritma dan fungsionalitas lengkap untuk image processing.
#
# Matplotlib : visualisasi data seperti membuat berbagai jenis plot/grafik seperti line, scatter, histogram, bar chart, pie chart, dll.
#
# Tidak semua dari library tersebut digunakan hanya numpy dan skiimage yang digunakan pada langkah ke 8
#
#
# 3. pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut,
#
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
# jawab :
# memperkecil ukuran gambar yang di-load dari sebuah url menggunakan library skimage dan OpenCV di Python menjadi 0,5 dari tinggi awal dan 0,5 dari lebar awal
# jika tidak ditambahkan maka gambar tidak akan diperkecil atau resize
#
#
# 4. perhatikan potongan kode program berikut :
#
#
#
#
# Apakah kegunaan kode [255,255,255] ? Jelaskan!
# Jawab :
# Membuat gambar garis putih ditengah layar menjadi berwarna putih
#
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah
# Jawab :
# Pixel adalah titik-titik yang penyusun sebuah gambar digital
# Resoulsi adalah ukuran pixel pada suatu gambar
# semakin tinggi resolusi semakin banyak jumlah pixel pada gambar dan sebaliknya semakin kecil resolusi semakin sedikit jumlah pixel pada gambar.

# %%
# langkah 3
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image : tinggi x lebar = ", tinggi , " x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image : tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %%
# langkah 4
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
# # membuat garis horizontal ditengah image
for y in range(lebar) :
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2,image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
# TUGAS 2
# 2. Buat garis vertikal dan garis menyilang diagonal pada image keluaran
# for x in range(tinggi):
#   image_3[x,int((lebar)/2)] = [255,255,255]
# final_frame = cv.hconcat((image_2,image_3))
# cv2_imshow(final_frame)

# # garis diagonal
for y in range (min(tinggi, lebar)):
  image_3[y, y] = [255,255,255]
for y in range (min(tinggi, lebar)):
  image_3[y, lebar - y - 1] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

# kotak putih ditengah
# for x in range(100,250):
#   for y in range(190,320):
#     image_3[x,y] = [255, 255, 255]


# final_frame = cv.hconcat((image_2, image_3))
# cv2_imshow(final_frame)

# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list

# langkah 2

# for url in urls:
#   image = io.imread(url)  # read image
#   image = cv.resize(image,(0,0),fx=0.5, fy=0.5) #resize image
#   image_2 = cv.cvtColor(image,cv.COLOR_BGR2RGB) #conver color
#   final_frame = cv.hconcat((image,image_2)) #concatenate
# cv2_imshow(final_frame) # show image
# print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#Membuat garis horizontal berwarna putih di bagian tengah image
for x in range (tinggi):
  if(x >200 and x < 300):
    image_3[int((tinggi)/2),x] =[255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
urlKTP = cv.imread("/content/KTP.jpeg")
# cv2_imshow(urlKTP)

tinggi = urlKTP.shape[0]
lebar = urlKTP.shape[1]

# kotak putih ditengah
for x in range(280,298):
  for y in range(190,420):
    urlKTP[x,y] = [255, 125, 50]
for v in range(305,325):
  for w in range(190,420):
    urlKTP[v,w] = [0, 0, 255]

# final_frame = cv.hconcat((image_2, image_3))
print("tinggi ", tinggi ," lebar ", lebar)
cv2_imshow(urlKTP)
# Out:
# tinggi  488  lebar  800
# <PIL.Image.Image image mode=RGB size=800x488>

# %% [markdown]
# # New Section
